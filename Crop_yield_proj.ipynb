# %%
#importing the essential librabies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating a dataframe
df1=pd.read_csv(r"C:\Users\admin\Downloads\crop_production.csv")
df1
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
#printing the first 10 rows of the dataframe
df1.head(10)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop     Area  Production
# 0             Arecanut   1254.0      2000.0
# 1  Other Kharif pulses      2.0         1.0
# 2                 Rice    102.0       321.0
# 3               Banana    176.0       641.0
# ...

# %%
# To get the summary of dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
#To Check the Unique Values count at Each column
for i in df1.columns:
    print(f"Unique{i}'s count:{df1[i].nunique()}")
    print(f"{df1[i].unique()}\n")
# Out:
# UniqueState_Name's count:33
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir '
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana ' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']
#
# UniqueDistrict_Name's count:646
# ['NICOBARS' 'NORTH AND MIDDLE ANDAMAN' 'SOUTH ANDAMANS' 'ANANTAPUR'
#  'CHITTOOR' 'EAST GODAVARI' 'GUNTUR' 'KADAPA' 'KRISHNA' 'KURNOOL'
#  'PRAKASAM' 'SPSR NELLORE' 'SRIKAKULAM' 'VISAKHAPATANAM' 'VIZIANAGARAM'
#  'WEST GODAVARI' 'ANJAW' 'CHANGLANG' 'DIBANG VALLEY' 'EAST KAMENG'
#  'EAST SIANG' 'KURUNG KUMEY' 'LOHIT' 'LONGDING' 'LOWER DIBANG VALLEY'
#  'LOWER SUBANSIRI' 'NAMSAI' 'PAPUM PARE' 'TAWANG' 'TIRAP' 'UPPER SIANG'
# ...

# %%
#calculating the mean of production Column
prod_mean=df1['Production'].mean()
prod_mean
# Out:
# 582503.4422509808

# %%
#calculating the standard Deviation of Production Column
prod_std=df1['Production'].std()
prod_std
# Out:
# 17065813.172410313

# %%
#Calculating the sum of null values of production Column
null_sum=df1['Production'].isnull().sum()
null_sum
# Out:
# 3730

# %%
# Replacing the NaN values with Generated random values
rand_values=np.random.randint(prod_mean-prod_std,prod_mean+prod_std,size=null_sum)
prod_slice=df1['Production'].copy()
prod_slice[np.isnan(prod_slice)]=rand_values
df1['Production']=prod_slice
df1['Production']=df1['Production'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     246091 non-null  int32
# dtypes: float64(1), int32(1), int64(1), object(4)
# memory usage: 12.2+ MB

# %% [markdown]
# Now , here is no null values.

# %%
state_names=df1.State_Name.value_counts().index
state_names
# Out:
# Index(['Uttar Pradesh', 'Madhya Pradesh', 'Karnataka', 'Bihar', 'Assam',
#        'Odisha', 'Tamil Nadu', 'Maharashtra', 'Rajasthan', 'Chhattisgarh',
#        'Andhra Pradesh', 'West Bengal', 'Gujarat', 'Haryana', 'Telangana ',
#        'Uttarakhand', 'Kerala', 'Nagaland', 'Punjab', 'Meghalaya',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Jammu and Kashmir ',
#        'Tripura', 'Manipur', 'Jharkhand', 'Mizoram', 'Puducherry', 'Sikkim',
#        'Dadra and Nagar Haveli', 'Goa', 'Andaman and Nicobar Islands',
#        'Chandigarh'],
#       dtype='object')

# %%
state_values=df1.State_Name.value_counts().values
state_values
# Out:
# array([33306, 22943, 21122, 18885, 14628, 13575, 13547, 12628, 12514,
#        10709,  9628,  9613,  8436,  5875,  5649,  4896,  4261,  3906,
#         3173,  2867,  2546,  2494,  1634,  1412,  1267,  1266,   957,
#          876,   714,   263,   208,   203,    90], dtype=int64)

# %%
#Making Bar Plot
sns.barplot(x=state_values,y=state_names)
# Out:
# <Axes: >

# %% [markdown]
# now we can say that as per the above bar graph, 1.Uttar pradesh, Madhya Pradesh and Karnataka these are Top3 the states of India who contributes majorly for Forming. 2.And Goa, Andaman and NicobarIslands and Chandigarh in these states Farming is very less.

# %%
Crops_name=df1.Crop.value_counts().index
Crops_name
# Out:
# Index(['Rice', 'Maize', 'Moong(Green Gram)', 'Urad', 'Sesamum', 'Groundnut',
#        'Sugarcane', 'Wheat', 'Rapeseed &Mustard', 'Arhar/Tur',
#        ...
#        'Jobster', 'Perilla', 'Turnip', 'Pear', 'Plums', 'Litchi', 'Coffee',
#        'Apple', 'Peach', 'Other Dry Fruit'],
#       dtype='object', length=124)

# %%
Crops_value=df1.Crop.value_counts().values
Crops_value
# Out:
# array([15104, 13947, 10318,  9850,  9046,  8834,  7921,  7899,  7592,
#         7578,  7361,  7065,  7012,  6931,  6489,  5571,  5427,  4652,
#         4524,  4518,  4405,  4224,  4202,  4199,  4198,  4145,  3902,
#         3659,  3376,  3369,  3289,  3212,  3209,  3180,  3008,  2698,
#         2395,  2070,  1985,  1787,  1586,  1577,  1453,  1360,  1335,
#         1295,  1081,   934,   878,   633,   628,   587,   483,   479,
#          449,   427,   426,   410,   386,   381,   368,   301,   297,
#          271,   266,   247,   241,   236,   205,   188,   167,   129,
#          126,   122,   118,   112,   112,    93,    93,    92,    87,
#           85,    84,    82,    70,    69,    66,    62,    61,    58,
#           48,    44,    39,    39,    38,    36,    35,    31,    29,
#           28,    21,    20,    20,    20,    20,    18,    18,    16,
#           12,    11,    11,    11,    10,    10,     9,     9,     8,
# ...

# %%
sns.barplot(x=Crops_value,y=Crops_name,data=df1)
# Out:
# <Axes: >

# %%
#To get the descriptive analysis
df1.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.460910e+05
# mean     2005.643018  1.200282e+04  5.802080e+05
# std         4.952164  5.052340e+04  1.697926e+07
# min      1997.000000  4.000000e-02 -1.647988e+07
# 25%      2002.000000  8.000000e+01  8.400000e+01
# 50%      2006.000000  5.820000e+02  7.300000e+02
# 75%      2010.000000  4.392000e+03  7.333000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
numerical_fea=[feature for feature in df1.columns if df1[feature].dtypes!='O']
numerical_fea
# Out:
# ['Crop_Year', 'Area', 'Production']

# %%
corr=df1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6188\619235471.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df1.corr()
# <Axes: >

# %%
df1.groupby('Crop_Year')['Production'].median().plot()
plt.xlabel('Crop_Year')
plt.ylabel('Median production')
# Out:
# Text(0, 0.5, 'Median production')

# %%
sns.boxplot(y=np.log(df1['Production']))
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: ylabel='Production'>

# %%
sns.boxplot(x=np.log(df1['Area']))
# Out:
# <Axes: xlabel='Area'>

# %%
df2=pd.read_csv(r"C:\Users\admin\Downloads\cpdata.csv")
df2
# Out:
#       temperature   humidity        ph    rainfall       label
# 0       20.879744  82.002744  6.502985  202.935536        rice
# 1       21.770462  80.319644  7.038096  226.655537        rice
# 2       23.004459  82.320763  7.840207  263.964248        rice
# 3       26.491096  80.158363  6.980401  242.864034        rice
# 4       20.130175  81.604873  7.628473  262.717340        rice
# ...           ...        ...       ...         ...         ...
# 3095    25.287846  89.636679  6.765095   58.286977  watermelon
# 3096    26.638386  84.695469  6.189214   48.324286  watermelon
# 3097    25.331045  84.305338  6.904242   41.532187  watermelon
# 3098    26.897502  83.892415  6.463271   43.971937  watermelon
# 3099    26.986037  89.413849  6.260839   58.548767  watermelon
#
# [3100 rows x 5 columns]

# %%
df2.head(10)
# Out:
#    temperature   humidity        ph    rainfall label
# 0    20.879744  82.002744  6.502985  202.935536  rice
# 1    21.770462  80.319644  7.038096  226.655537  rice
# 2    23.004459  82.320763  7.840207  263.964248  rice
# 3    26.491096  80.158363  6.980401  242.864034  rice
# 4    20.130175  81.604873  7.628473  262.717340  rice
# 5    23.058049  83.370118  7.073454  251.055000  rice
# 6    22.708838  82.639414  5.700806  271.324860  rice
# 7    20.277744  82.894086  5.718627  241.974195  rice
# 8    24.515881  83.535216  6.685346  230.446236  rice
# 9    23.223974  83.033227  6.336254  221.209196  rice

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  3100 non-null   float64
#  1   humidity     3100 non-null   float64
#  2   ph           3100 non-null   float64
#  3   rainfall     3100 non-null   float64
#  4   label        3100 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 121.2+ KB

# %%
c_n=df2.label.value_counts().index
c_v=df2.label.value_counts().values

# %%
df2.describe()
# Out:
#        temperature     humidity           ph     rainfall
# count  3100.000000  3100.000000  3100.000000  3100.000000
# mean     27.108466    66.005312     6.368913   110.213031
# std       7.566308    24.007713     0.809477    64.048562
# min       8.825675    10.034048     3.504752    20.211267
# 25%      22.810495    55.244920     5.895343    64.909095
# 50%      26.102848    68.980529     6.342518    97.057093
# 75%      29.365644    84.446524     6.841616   141.210784
# max      54.986760    99.981876     9.935091   397.315380

# %%
sns.barplot(x='rainfall',y='label',data=df2)
# Out:
# <Axes: xlabel='rainfall', ylabel='label'>

# %%
df3=pd.read_csv(r"C:\Users\admin\Downloads\cropph.csv")
df3
# Out:
#                      Crop    Ph
# 0                   Bajra  3.00
# 1                  Banana  6.50
# 2                  Barley  3.00
# 3                    Bean  5.50
# 4            Black pepper  6.40
# 5               Blackgram  5.00
# 6            Bottle Gourd  6.50
# 7                 Brinjal  5.50
# 8                 Cabbage  5.50
# 9                Cardamom  4.50
# 10                 Carrot  5.50
# 11            Castor seed  5.00
# 12            Cauliflower  6.00
# 13               Chillies  5.50
# 14              Colocosia  5.50
# 15              Coriander  8.00
# 16                 Cotton  7.00
# 17                 Cowpea  6.00
# 18             Drum Stick  6.40
# 19                 Garlic  6.10
# 20                 Ginger  5.00
# 21                   Gram  6.10
# 22                 Grapes  6.50
# 23              Groundnut  5.00
# 24              Guar seed  5.00
# 25             Horse-gram  5.00
# 26                  Jowar  6.00
# 27                   Jute  7.40
# ...

# %%
df3.describe()
# Out:
#               Ph
# count  58.000000
# mean    5.727759
# std     1.014469
# min     3.000000
# 25%     5.000000
# 50%     5.550000
# 75%     6.375000
# max     8.000000

# %%
df4=pd.read_csv(r"C:\Users\admin\Downloads\state_wise_crop_production.csv")
df4
# Out:
#                     Crop           State  \
# 0                  ARHAR   Uttar Pradesh
# 1                  ARHAR       Karnataka
# 2                  ARHAR         Gujarat
# 3                  ARHAR  Andhra Pradesh
# 4                  ARHAR     Maharashtra
# 5                 COTTON     Maharashtra
# 6                 COTTON          Punjab
# 7                 COTTON  Andhra Pradesh
# 8                 COTTON         Gujarat
# 9                 COTTON         Haryana
# 10                  GRAM       Rajasthan
# 11                  GRAM  Madhya Pradesh
# 12                  GRAM   Uttar Pradesh
# 13                  GRAM     Maharashtra
# 14                  GRAM  Andhra Pradesh
# 15             GROUNDNUT       Karnataka
# 16             GROUNDNUT  Andhra Pradesh
# 17             GROUNDNUT      Tamil Nadu
# 18             GROUNDNUT         Gujarat
# 19             GROUNDNUT     Maharashtra
# 20                 MAIZE           Bihar
# 21                 MAIZE       Karnataka
# ...

# %%
df4.columns=["Crop","State","Cost of Cultivation (`/Hectare) A2+FL","Cost of Cultivation (`/Hectare) C2","Cost of Production (`/Quintal) C2","Yield"]

# %%
df4.columns
# Out:
# Index(['Crop', 'State', 'Cost of Cultivation (`/Hectare) A2+FL',
#        'Cost of Cultivation (`/Hectare) C2',
#        'Cost of Production (`/Quintal) C2', 'Yield'],
#       dtype='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Crop                                   49 non-null     object
#  1   State                                  49 non-null     object
#  2   Cost of Cultivation (`/Hectare) A2+FL  49 non-null     float64
#  3   Cost of Cultivation (`/Hectare) C2     49 non-null     float64
#  4   Cost of Production (`/Quintal) C2      49 non-null     float64
#  5   Yield                                  49 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 2.4+ KB

# %%
df4.describe()
# Out:
#        Cost of Cultivation (`/Hectare) A2+FL  \
# count                              49.000000
# mean                            20363.537347
# std                             13561.435306
# min                              5483.540000
# 25%                             12774.410000
# 50%                             17022.000000
# 75%                             24731.060000
# max                             66335.060000
#
#        Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# count                           49.000000                          49.000000
# mean                         31364.666735                        1620.537755
# std                          20095.783569                        1104.990472
# min                           7868.640000                          85.790000
# 25%                          19259.840000                         732.620000
# 50%                          25909.050000                        1595.560000
# ...

# %%
df4.corr()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6188\3006967730.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4.corr()
#                                        Cost of Cultivation (`/Hectare) A2+FL  \
# Cost of Cultivation (`/Hectare) A2+FL                               1.000000
# Cost of Cultivation (`/Hectare) C2                                  0.981225
# Cost of Production (`/Quintal) C2                                  -0.434422
# Yield                                                               0.863400
#
#                                        Cost of Cultivation (`/Hectare) C2  \
# Cost of Cultivation (`/Hectare) A2+FL                            0.981225
# Cost of Cultivation (`/Hectare) C2                               1.000000
# ...

# %%
sns.boxplot(x=df4["Cost of Production (`/Quintal) C2"])
# Out:
# <Axes: xlabel='Cost of Production (`/Quintal) C2'>

# %%
x=df4[["Cost of Cultivation (`/Hectare) A2+FL","Cost of Cultivation (`/Hectare) C2","Cost of Production (`/Quintal) C2"]]
y=df4["Yield"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -119.21811311656785

# %%
model.coef_
# Out:
# array([ 0.015692  , -0.0017596 , -0.03021745])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 186.60175252,   45.6797465 ,  175.57403257, -104.92694945,
#         604.76050248,  107.57182311,  117.85293178,  188.61701198,
#         598.83876841,   87.85103996,  -64.80453444,  -41.9612724 ,
#          -6.67306443,  129.95892687,  -52.7323602 ])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 108.95507835386152

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 19458.178887678714

# %%
np.sqrt(mse)
# Out:
# 139.49257646082359

# %%
df5=pd.read_csv(r"C:\Users\admin\Downloads\cropproductiononvariousfactors.csv")
df5
# Out:
#          Rainfall  Temperature   Ph   Crop  Production Cropconversion
# 0       400.15082         20.0  3.0  Bajra     0.00690          Bajra
# 1       400.16331         20.0  3.2  Bajra     0.00747          Bajra
# 2       400.16387         20.0  3.2  Bajra     0.00749          Bajra
# 3       400.17967         20.0  3.2  Bajra     0.00822          Bajra
# 4       400.19582         20.0  3.2  Bajra     0.00895          Bajra
# ...           ...          ...  ...    ...         ...            ...
# 189227  766.92202         23.0  6.0  Wheat    10.40000          Wheat
# 189228  770.28486         27.0  6.0  Wheat    10.40000          Wheat
# 189229  770.00000         26.0  6.1  Wheat    10.40000          Wheat
# 189230  633.83459         22.0  6.2  Wheat    10.40000          Wheat
# 189231  761.20623         22.0  6.2  Wheat    10.40000          Wheat
#
# [189232 rows x 6 columns]

# %%
df5.sample(25)
# Out:
#           Rainfall  Temperature   Ph                   Crop  Production  \
# 182565   631.74944     22.00000  5.7                  Wheat     0.40240
# 101497   614.00000     23.35500  6.1                  Onion    14.25000
# 84587    770.00000     29.23909  6.5                  Maize     7.33003
# 52210    810.00500     30.87379  6.7              Groundnut     2.30189
# 161672   496.45094     24.50500  6.7              Sunflower     1.92902
# 75649    564.81865     30.40978  5.9                  Maize     1.44041
# 25140    777.77778     21.00000  8.0              Coriander     0.55556
# 29204    523.22657     27.00000  7.2                 Cotton     2.32266
# 169286  1525.26316     28.00000  6.0               Turmeric     1.26316
# 150963  1015.15909     28.50000  6.1              Sugarcane    38.38636
# 92781    648.46154     25.44000  6.8      Moong(Green Gram)     0.53846
# 18678    675.22599     18.90000  6.1               Chillies     0.71751
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189232 entries, 0 to 189231
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Rainfall        189232 non-null  float64
#  1   Temperature     189232 non-null  float64
#  2   Ph              189232 non-null  float64
#  3   Crop            189232 non-null  object
#  4   Production      189232 non-null  float64
#  5   Cropconversion  189232 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 8.7+ MB

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=11,8
sns.barplot(x='Production',y='Crop',data=df5)
# Out:
# <Axes: xlabel='Production', ylabel='Crop'>

# %%
df5=df5[["Rainfall","Temperature","Ph"]].astype(int)

# %%
sns.boxplot(x=df5["Rainfall"])
# Out:
# <Axes: xlabel='Rainfall'>

# %%
df5.corr()
# Out:
#              Rainfall  Temperature        Ph
# Rainfall     1.000000     0.010946  0.094960
# Temperature  0.010946     1.000000 -0.064525
# Ph           0.094960    -0.064525  1.000000
